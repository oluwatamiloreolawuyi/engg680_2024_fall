# %% [markdown]
# # **ENGG680 - Introduction to Digital Engineering**
# ## *Lab Assignment 1: Using Git and Python for Collaborative Coding in Google Colab*

# %% [markdown]
# ## Preliminary: Certificate of Work
# ### (5 Marks)

# %% [markdown]
# *We, the undersigned, certify that this is our own work, which has been done expressly for this course, either without the assistance of any other party or where appropriate we have acknowledged the work of others. Further, we have read and understood the section in the university calendar on plagiarism/cheating/other academic misconduct and we are aware of the implications thereof. We request that the total mark for this assignment be distributed as follows among group members:*

# %% [markdown]
# |          | First Name | Last Name | Signature (Full Name, Date) | Hours | Contribution % |
# |----------|------------|-----------|-----------------------------|-------|----------------|
# | Member 1: | Oluwtamilore | Olawuyi | Oluwatamilore Olawuyi 29th of September 2024 | 2 Hours | 25% |
# | Member 2: | First Name | Last Name | Signature | Hours | Contribution |
# | Member 3: | First Name | Last Name | Signature | Hours | Contribution |
# | Member 4: | First Name | Last Name | Signature | Hours | Contribution |

# %% [markdown]
# ## Part 1: Printing to the Console
# ### (6 Marks)

# %%
# In the space below, please print "Hello, World! Welcome to the Student Gradebook Management System."
# (1 mark)

# %%
print("Hello, World! Welcome to the Student Gradebook Management System.")
# Out:
# Hello, World! Welcome to the Student Gradebook Management System.

# %%
# Fill in your information using the defined variables below:
# (1 mark)
lab_group_number =
intake_year =
intake_semester = "" #"Fall" or "Winter"

# Using f-strings and the variables above, print "This is implemented by Group <lab_group_number>, for ENGG680 <intake_semester> of <intake_year>"
# (2 marks)

# %%
lab_group_number = 38
intake_year = 2024
intake_semester = "Fall"

print(f"This is implemented by Group {lab_group_number}, for ENGG680 {intake_semester} of {intake_year}")
# Out:
# This is implemented by Group 38, for ENGG680 Fall of 2024

# %%
# Use indexing to print "The subjects involved in this grading system is English and Math." using "subjects" below.
# (2 marks)
subjects = ("English", "Math")

# %%
subjects = ("English", "Math")
print(f"The subjects involved in this grading system is {subjects[0]} and {subjects[1]}.")
# Out:
# The subjects involved in this grading system is English and Math.

# %% [markdown]
# ## Part 2: Using Pandas for Data Management and Analytics
# ### (20 marks)

# %%
# In the space below, please import the Pandas library
# (1 mark)
import pandas as pd

# %%
# Load the student grade CSV files into DataFrames using the defined variables
# (2 marks)
df_english =
df_math =

# %%
import pandas as pd
# !wget https://drive.google.com/uc?id=1xY_F4xhJV9NXyfjks3EtA8b9f7u1BWFh -O english_grades.csv
# !wget https://drive.google.com/uc?id=1N5KuPHi5jfzsAe32N1IpAuP5dmCpnezm -O math_grades.csv
df_english = pd.read_csv('english_grades.csv')
df_math = pd.read_csv('math_grades.csv')
# Out:
# --2024-09-23 23:50:12--  https://drive.google.com/uc?id=1xY_F4xhJV9NXyfjks3EtA8b9f7u1BWFh
# Resolving drive.google.com (drive.google.com)... 173.194.174.138, 173.194.174.100, 173.194.174.139, ...
# Connecting to drive.google.com (drive.google.com)|173.194.174.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1xY_F4xhJV9NXyfjks3EtA8b9f7u1BWFh [following]
# --2024-09-23 23:50:12--  https://drive.usercontent.google.com/download?id=1xY_F4xhJV9NXyfjks3EtA8b9f7u1BWFh
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.8.132, 2404:6800:4008:c15::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.8.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 362 [application/octet-stream]
# Saving to: ‘english_grades.csv’
#
# english_grades.csv  100%[===================>]     362  --.-KB/s    in 0s
#
# 2024-09-23 23:50:14 (19.8 MB/s) - ‘english_grades.csv’ saved [362/362]
#
# --2024-09-23 23:50:15--  https://drive.google.com/uc?id=1N5KuPHi5jfzsAe32N1IpAuP5dmCpnezm
# Resolving drive.google.com (drive.google.com)... 173.194.174.138, 173.194.174.100, 173.194.174.139, ...
# Connecting to drive.google.com (drive.google.com)|173.194.174.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1N5KuPHi5jfzsAe32N1IpAuP5dmCpnezm [following]
# --2024-09-23 23:50:15--  https://drive.usercontent.google.com/download?id=1N5KuPHi5jfzsAe32N1IpAuP5dmCpnezm
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.8.132, 2404:6800:4008:c15::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.8.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 360 [application/octet-stream]
# Saving to: ‘math_grades.csv’
#
# math_grades.csv     100%[===================>]     360  --.-KB/s    in 0s
#
# 2024-09-23 23:50:17 (5.56 MB/s) - ‘math_grades.csv’ saved [360/360]

# %%
# Merging the DataFrames on 'studentID'
df_studentGrades = pd.merge(df_english, df_math, on='studentID', suffixes=('_English', '_Math'))

# %%
df_studentGrades = pd.merge(df_english, df_math, on='studentID', suffixes=('_English', '_Math'))

# %%
# Take a look at the data contained in the csv files. Why is studentID chosen as the key?
# (1 mark)

# %%
print("English Grades:")
print(df_english)
print("Math Grades:")
print(df_math)
# Out:
# English Grades:
#    firstName  lastName  studentID  grade
# 0       Emma     Smith      10959     95
# 1     Sophia  Robinson      75175     88
# 2       Emma    Taylor      42257     87
# 3      David  Robinson      55148     86
# 4    Stephen     Curry      30303     90
# 5   Isabella  Thompson      72824     88
# 6    Jasmine     Smith      70385     84
# 7      James     Jones      87707     76
# 8      Sarah     Swift      61026     80
# 9       Anne     Clark      90449     82
# 10      Ryan    Thomas      62137     92
# 11    Daniel     White      25477     91
# 12      Sara       Doe      47991     98
# 13   Matthew     White      25376     80
# Math Grades:
#    firstName  lastName  studentID  grade
# 0      James     Jones      87707     92
# 1      Sarah     Swift      61026     98
# 2       Anne     Clark      90449     99
# 3       Ryan    Thomas      62137     89
# 4     Daniel     White      25477     87
# 5       Sara       Doe      47991     86
# 6    Matthew     White      25376     85
# 7       Emma     Smith      10959     90
# 8     Sophia  Robinson      75175     95
# 9       Emma    Taylor      42257     85
# 10     David  Robinson      55148     87
# 11   Stephen     Curry      30303     88
# 12  Isabella  Thompson      72824     79
# 13   Jasmine     Smith      70385     80

# %% [markdown]
# Student ID is taken as the key because it is the unique identifer of each student

# %%
# Let's calculate the average GPA across the two classes for each student
df_studentGrades['GPA'] = df_studentGrades[['grade_English', 'grade_Math']].mean(axis=1)

# Now let's check the data! In the space below, please use the .head method to display the dataframe.
# (1 mark)

# %%
df_studentGrades['GPA'] = df_studentGrades[['grade_English', 'grade_Math']].mean(axis=1)

# %%
print(df_studentGrades.head())
# Out:
#   firstName_English lastName_English  studentID  grade_English firstName_Math  \
# 0              Emma            Smith      10959             95           Emma
# 1            Sophia         Robinson      75175             88         Sophia
# 2              Emma           Taylor      42257             87           Emma
# 3             David         Robinson      55148             86          David
# 4           Stephen            Curry      30303             90        Stephen
#
#   lastName_Math  grade_Math   GPA
# 0         Smith          90  92.5
# 1      Robinson          95  91.5
# 2        Taylor          85  86.0
# 3      Robinson          87  86.5
# 4         Curry          88  89.0

# %%
# Do you notice a problem? The rows for first name and last name have been duplicated!
# .drop(columns=['<column_name1>','<column_name2>'] is a Pandas method that can be used to drop columns.
# In the space below, drop the first name and last name associated with the math .csv file.
# (2 mark)
df_studentGrades =

# %%
df_studentGrades = df_studentGrades.drop(columns=['firstName_Math','lastName_Math'])

# %%
# Let's display the data again. Use an appropriate method (hint: already used before)
# (1 mark)
#

# %%
print(df_studentGrades.head())
# Out:
#   firstName_English lastName_English  studentID  grade_English  grade_Math  \
# 0              Emma            Smith      10959             95          90
# 1            Sophia         Robinson      75175             88          95
# 2              Emma           Taylor      42257             87          85
# 3             David         Robinson      55148             86          87
# 4           Stephen            Curry      30303             90          88
#
#     GPA
# 0  92.5
# 1  91.5
# 2  86.0
# 3  86.5
# 4  89.0

# %%
# Let's also rename the first and last names appropriately.
# Complete the code in the space below by replacing "<>" with the proper column name
# (1 mark)

df_studentGrades = df_studentGrades.rename(columns={
    'firstName_English': 'firstName',
    '<>': 'lastName',
    '<>': 'englishGrade',
    '<>': 'mathGrade'
    })

# %%
df_studentGrades = df_studentGrades.rename(columns={
    'firstName_English': 'firstName',
    'lastName_English': 'lastName',
    'grade_English': 'englishGrade',
    '<grade_Math>': 'mathGrade'
    })

# %%
# Now let's find out some statistics about our student grades!
# Please use an appropriate Pandas method in the space below to display statistical values like
# mean, standard deviation, min, max, and others.
# (1 mark)
#

# %%
df_studentGrades.describe()
# Out:
#        englishGrade  grade_Math       GPA  mathGrade
# count     14.000000   14.000000  14.00000  14.000000
# mean      86.928571   88.571429  87.75000  88.571429
# std        6.145221    5.918865   3.63609   5.918865
# min       76.000000   79.000000  82.00000  79.000000
# 25%       82.500000   85.250000  84.50000  85.250000
# 50%       87.500000   87.500000  89.00000  87.500000
# 75%       90.750000   91.500000  90.50000  91.500000
# max       98.000000   99.000000  92.50000  99.000000

# %%
# Do you notice a problem?
# Some statistics are not relevant. The average of studentIDs have no meaning in reality!
# Let's typecast each column appropriately so as to only get meaningful statistics.
# In the code below, replace '<>' by choosing between 'str' for string or 'float' for float
# to properly typecast each column.
# (3 marks)
df_studentGrades['studentID'] = df_studentGrades['studentID'].astype(<>)
df_studentGrades['firstName'] = df_studentGrades['firstName'].astype(<>)
df_studentGrades['lastName'] = df_studentGrades['lastName'].astype(<>)
df_studentGrades['englishGrade'] = df_studentGrades['englishGrade'].astype(<>)
df_studentGrades['mathGrade'] = df_studentGrades['mathGrade'].astype(<>)
df_studentGrades['GPA'] = df_studentGrades['GPA'].astype(<>)

# %%
df_studentGrades['studentID'] = df_studentGrades['studentID'].astype('str')
df_studentGrades['firstName'] = df_studentGrades['firstName'].astype('str')
df_studentGrades['lastName'] = df_studentGrades['lastName'].astype('str')
df_studentGrades['englishGrade'] = df_studentGrades['englishGrade'].astype('float')
df_studentGrades['mathGrade'] = df_studentGrades['grade_Math'].astype('float')
df_studentGrades['GPA'] = df_studentGrades['GPA'].astype('float')

# %%
# Now let's see our statistics!
df_studentGrades.describe()

# %%
df_studentGrades.describe()
# Out:
#        englishGrade  grade_Math       GPA  mathGrade
# count     14.000000   14.000000  14.00000  14.000000
# mean      86.928571   88.571429  87.75000  88.571429
# std        6.145221    5.918865   3.63609   5.918865
# min       76.000000   79.000000  82.00000  79.000000
# 25%       82.500000   85.250000  84.50000  85.250000
# 50%       87.500000   87.500000  89.00000  87.500000
# 75%       90.750000   91.500000  90.50000  91.500000
# max       98.000000   99.000000  92.50000  99.000000

# %%
# Now sort the merged dataframe so that it is in descending order based on GPA, and print it
# (1 mark)
df_studentsGPASorted =

# %%
df_studentsGPASorted = df_studentGrades.sort_values(by='GPA', ascending=False)

# %%
# If we wanted to access the student with the highest gpa based on df_studentsGPASorted,
# does .iloc or .loc make more sense and why?
# (2 marks)
#

# %% [markdown]
# Using .iloc makes more sense becuse it is easier to acces the first value on the table since its already sorted

# %%
# Now using the method you specified, assign the variable below to the row containing the student with the highest GPA
# (1 mark)
top_student =

# %%
top_student = df_studentsGPASorted.iloc[0]

# %%
# Now print the student first name and last name with the highest GPA in this format:
# "The student with the highest GPA is <firstName> <lastName> with a GPA of <GPA>"
# (1 mark)
#

# %%
print(f"The student with the highest GPA is {top_student['firstName']} {top_student['lastName']} with a GPA of {top_student['GPA']}")
# Out:
# The student with the highest GPA is Emma Smith with a GPA of 92.5

# %%
# We can use logical expressions to filter and print data. For example, let's print the students with math grades higher than 90:
df_mathGrade_over90 = df_studentsGPASorted[df_studentsGPASorted['mathGrade'] > 90]
print(df_mathGrade_over90)

# %%
df_mathGrade_over90 = df_studentsGPASorted[df_studentsGPASorted['mathGrade'] > 90]
print(df_mathGrade_over90)
# Out:
#   firstName  lastName studentID  englishGrade  grade_Math   GPA  mathGrade
# 1    Sophia  Robinson     75175          88.0          95  91.5       95.0
# 9      Anne     Clark     90449          82.0          99  90.5       99.0
# 8     Sarah     Swift     61026          80.0          98  89.0       98.0
# 7     James     Jones     87707          76.0          92  84.0       92.0

# %%
# Now print the students whos GPA are lower than 85
# (2 marks)
#

# %%
df_GPA_lower85 = df_studentsGPASorted[df_studentsGPASorted['GPA'] < 85]
print(df_GPA_lower85)
# Out:
#    firstName  lastName studentID  englishGrade  grade_Math   GPA  mathGrade
# 7      James     Jones     87707          76.0          92  84.0       92.0
# 5   Isabella  Thompson     72824          88.0          79  83.5       79.0
# 13   Matthew     White     25376          80.0          85  82.5       85.0
# 6    Jasmine     Smith     70385          84.0          80  82.0       80.0

# %% [markdown]
# ## Part 3: More Data Analytics using Pandas
# ### (20 marks)

# %%
# Select the column 'grade' from the original English grade dataset and print it
# (1 mark)
#

# %%
column_grade = df_english['grade']
print(column_grade)
# Out:
# 0     95
# 1     88
# 2     87
# 3     86
# 4     90
# 5     88
# 6     84
# 7     76
# 8     80
# 9     82
# 10    92
# 11    91
# 12    98
# 13    80
# Name: grade, dtype: int64

# %%
# Select the column 'GPA' from the df_studentGrades and print it
# (1 mark)
#

# %%
column_GPA = df_studentGrades['GPA']
print(column_GPA)
# Out:
# 0     92.5
# 1     91.5
# 2     86.0
# 3     86.5
# 4     89.0
# 5     83.5
# 6     82.0
# 7     84.0
# 8     89.0
# 9     90.5
# 10    90.5
# 11    89.0
# 12    92.0
# 13    82.5
# Name: GPA, dtype: float64

# %%
# What is the data type of grade from the English grade dataset?
# (0.5 mark)
#

# What is the data type of GPA from the merged dataset?
# (0.5 mark)
#

# Is it different? Why?
# (1 mark)
#

# %%
print(df_english['grade'].dtype)
print(df_studentGrades['GPA'].dtype)
# Out:
# int64
# float64

# %% [markdown]
# It is diffrent because the data type for english grade is an integer while for GPA it is a floating point number because it requires accuracy since it the average of grades

# %%
# Load the student homeroom CSV file into a DataFrame using the following variable name
# (1 mark)
df_homeroom =

# %%
# !wget https://drive.google.com/uc?id=10WJOLaEK9nZdIhL9_qH8BcQMmBuyz5cc -O student_homeroom.csv
df_homeroom = pd.read_csv('student_homeroom.csv')
# Out:
# --2024-09-24 01:11:26--  https://drive.google.com/uc?id=10WJOLaEK9nZdIhL9_qH8BcQMmBuyz5cc
# Resolving drive.google.com (drive.google.com)... 173.194.174.139, 173.194.174.100, 173.194.174.101, ...
# Connecting to drive.google.com (drive.google.com)|173.194.174.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=10WJOLaEK9nZdIhL9_qH8BcQMmBuyz5cc [following]
# --2024-09-24 01:11:26--  https://drive.usercontent.google.com/download?id=10WJOLaEK9nZdIhL9_qH8BcQMmBuyz5cc
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.8.132, 2404:6800:4008:c15::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.8.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 379 [application/octet-stream]
# Saving to: ‘student_homeroom.csv’
#
# student_homeroom.cs 100%[===================>]     379  --.-KB/s    in 0s
#
# 2024-09-24 01:11:29 (12.0 MB/s) - ‘student_homeroom.csv’ saved [379/379]

# %%
# Merge the studentHomerooms with the merged dataset. Make sure that the key you are joining on are the same typecast for both datasets.
# Also ensure that there are no redundant columns, and finally display the first few rows.
# Hint: try joining on more than one column to avoid having to drop redundant columns, ie. on=['studentID', '<ColumnA>', '<ColumnB>'] ...
# (5 marks)
#

# %%
df_studentGrades['studentID'] = df_studentGrades['studentID'].astype(str)
df_homeroom['studentID'] = df_homeroom['studentID'].astype(str
)

# %%
print(pd.merge(df_studentGrades, df_homeroom, on=['studentID', 'firstName', 'lastName']).head())
# Out:
#   firstName  lastName studentID  englishGrade  mathGrade   GPA  homeRoom
# 0      Emma     Smith     10959          95.0         90  92.5       313
# 1    Sophia  Robinson     75175          88.0         95  91.5       311
# 2      Emma    Taylor     42257          87.0         85  86.0       311
# 3     David  Robinson     55148          86.0         87  86.5       313
# 4   Stephen     Curry     30303          90.0         88  89.0       313

# %%
#Detour Formatting
df_studentGrades = df_studentGrades.drop(columns=['mathGrade'])
df_studentGrades = df_studentGrades.rename(columns={'grade_Math': 'mathGrade'})

# %%
print(df_studentGrades)
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA
# 0       Emma     Smith     10959          95.0         90  92.5
# 1     Sophia  Robinson     75175          88.0         95  91.5
# 2       Emma    Taylor     42257          87.0         85  86.0
# 3      David  Robinson     55148          86.0         87  86.5
# 4    Stephen     Curry     30303          90.0         88  89.0
# 5   Isabella  Thompson     72824          88.0         79  83.5
# 6    Jasmine     Smith     70385          84.0         80  82.0
# 7      James     Jones     87707          76.0         92  84.0
# 8      Sarah     Swift     61026          80.0         98  89.0
# 9       Anne     Clark     90449          82.0         99  90.5
# 10      Ryan    Thomas     62137          92.0         89  90.5
# 11    Daniel     White     25477          91.0         87  89.0
# 12      Sara       Doe     47991          98.0         86  92.0
# 13   Matthew     White     25376          80.0         85  82.5

# %%
# The code below calculates the mean of each homeroom class.
df_grouped = df_studentInfo.groupby('homeRoom')['GPA'].mean()

# Which homeroom has a higher GPA?
# (1 mark)
#

# %%
df_studentInfo = pd.merge(df_studentGrades, df_homeroom, on=['studentID', 'firstName', 'lastName'])
df_grouped = df_studentInfo.groupby('homeRoom')['GPA'].mean()
print(df_grouped)
# Out:
# homeRoom
# 311    88.785714
# 313    86.714286
# Name: GPA, dtype: float64

# %% [markdown]
# Homeroom 311 has a higher GPA

# %%
# Now let's work with multiple sorts. The .sort_values() method can sort by multiple columns, meaning you can specify a primary column and a secondary column for sorting.
# For example, by=['ColumnA', 'ColumnB'] will first sort by ColumnA and then by ColumnB.
# Create and print a DataFrame, df_studentsGPASorted_homeroom, which is sorted by homeRoom and then by GPA, both in descending order.
# (3 mark)
#

# %%
df_studentsGPASorted_homeroom = df_studentInfo.sort_values(by=['homeRoom', 'GPA'], ascending=[True, False])
print(df_studentsGPASorted_homeroom)
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA  homeRoom
# 12      Sara       Doe     47991          98.0         86  92.0       311
# 1     Sophia  Robinson     75175          88.0         95  91.5       311
# 9       Anne     Clark     90449          82.0         99  90.5       311
# 8      Sarah     Swift     61026          80.0         98  89.0       311
# 11    Daniel     White     25477          91.0         87  89.0       311
# 2       Emma    Taylor     42257          87.0         85  86.0       311
# 5   Isabella  Thompson     72824          88.0         79  83.5       311
# 0       Emma     Smith     10959          95.0         90  92.5       313
# 10      Ryan    Thomas     62137          92.0         89  90.5       313
# 4    Stephen     Curry     30303          90.0         88  89.0       313
# 3      David  Robinson     55148          86.0         87  86.5       313
# 7      James     Jones     87707          76.0         92  84.0       313
# 13   Matthew     White     25376          80.0         85  82.5       313
# 6    Jasmine     Smith     70385          84.0         80  82.0       313

# %%
# Do you notice a problem with the indices? They are basically meaningless now that we have sorted by homeroom and GPA.

# The code below changes the index of the dataframe so that it is more intuitive.
df_studentsGPASorted_homeroom['studentRank'] = df_studentsGPASorted_homeroom.groupby('homeRoom').cumcount() + 1
df_studentsGPASorted_homeroom['newIndex'] = df_studentsGPASorted_homeroom['homeRoom'].astype(str) + '-' + df_studentsGPASorted_homeroom['studentRank'].astype(str)
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.set_index('newIndex')
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.drop(columns=['studentRank'])

print(df_studentsGPASorted_homeroom)

# %%
df_studentsGPASorted_homeroom['studentRank'] = df_studentsGPASorted_homeroom.groupby('homeRoom').cumcount() + 1
df_studentsGPASorted_homeroom['newIndex'] = df_studentsGPASorted_homeroom['homeRoom'].astype(str) + '-' + df_studentsGPASorted_homeroom['studentRank'].astype(str)
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.set_index('newIndex')
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.drop(columns=['studentRank'])

print(df_studentsGPASorted_homeroom)
# Out:
#          firstName  lastName studentID  englishGrade  mathGrade   GPA  \
# newIndex
# 311-1         Sara       Doe     47991          98.0         86  92.0
# 311-2       Sophia  Robinson     75175          88.0         95  91.5
# 311-3         Anne     Clark     90449          82.0         99  90.5
# 311-4        Sarah     Swift     61026          80.0         98  89.0
# 311-5       Daniel     White     25477          91.0         87  89.0
# 311-6         Emma    Taylor     42257          87.0         85  86.0
# 311-7     Isabella  Thompson     72824          88.0         79  83.5
# 313-1         Emma     Smith     10959          95.0         90  92.5
# 313-2         Ryan    Thomas     62137          92.0         89  90.5
# 313-3      Stephen     Curry     30303          90.0         88  89.0
# 313-4        David  Robinson     55148          86.0         87  86.5
# 313-5        James     Jones     87707          76.0         92  84.0
# 313-6      Matthew     White     25376          80.0         85  82.5
# 313-7      Jasmine     Smith     70385          84.0         80  82.0
#
#           homeRoom
# newIndex
# 311-1          311
# 311-2          311
# 311-3          311
# 311-4          311
# 311-5          311
# 311-6          311
# 311-7          311
# 313-1          313
# 313-2          313
# 313-3          313
# 313-4          313
# 313-5          313
# 313-6          313
# 313-7          313

# %%
# Describe what each coding line in the cell above is doing
# (4 marks)
#

# %% [markdown]
# df_studentsGPASorted_homeroom['studentRank'] = df_studentsGPASorted_homeroom.groupby('homeRoom').cumcount() + 1
#
# #This line of code figures out the rank of each student in their homeroom based on their grades then adds a 1 so it counts and ranks them from 1
#
# df_studentsGPASorted_homeroom['newIndex'] = df_studentsGPASorted_homeroom['homeRoom'].astype(str) + '-' + df_studentsGPASorted_homeroom['studentRank'].astype(str)
#
# #This line creates a new name of column by combining their homeroom and rank.It makes them a string and combines them.
#
# df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.set_index('newIndex')
#
# #This line replaces the old style of ID and assigns a new index based on theor poistion in the homeroom
#
# df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.drop(columns=['studentRank'])
#
# #This line of code removes the 'student rank' column so it wont have duplictate informationa and keep things tidy

# %%
# Given df_studentsGPASorted_homeroom, please find and print the students with the highest GPA in each homeroom using the .loc method.
# (2 marks)
#

# %%
print(df_studentsGPASorted_homeroom.loc[df_studentsGPASorted_homeroom.groupby('homeRoom')['GPA'].idxmax()])
# Out:
#          firstName lastName studentID  englishGrade  mathGrade   GPA  homeRoom
# newIndex
# 311-1         Sara      Doe     47991          98.0         86  92.0       311
# 313-1         Emma    Smith     10959          95.0         90  92.5       313

# %% [markdown]
# ## Part 4: Using Matplotlib for Data Analytics
# ### (14 marks)

# %%
# In the space below, please import the matplotlib library
# (1 mark)

# %%
import matplotlib.pyplot as plt

# %%
# Let's use matplotlib to display a histogram of the grades distribution
# Histograms are useful for seeing the distribution of the students grades

plt.figure(figsize=(10, 6))
plt.hist(df_studentGrades['englishGrade'], bins=10, alpha=0.7, label='English Grades', color='blue')

# Step 1: Use the line above as reference to create a histogram for the math grades
# (1 mark)
#

# Step 2: Ensure that your plot is descriptive, so use labels (x and y axis), a title, and a legend.
# Hint: Use the matplotlib .legend(loc='<location>') to add and place the legend.
# You can use 'upper left', 'upper right', 'lower left', and 'lower right' to specify the location.
# (4 marks)
#
plt.grid(True)

# Step 3: Use the .savefig('<image_title>'.png) to output an image file of the histogram.
# Please be sure to use a descriptive title!
# (1 mark)
#

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_studentGrades['englishGrade'], bins=10, alpha=0.7, label='English Grades', color='blue')
# Out:
# (array([1., 2., 1., 1., 1., 3., 2., 1., 1., 1.]),
#  array([76. , 78.2, 80.4, 82.6, 84.8, 87. , 89.2, 91.4, 93.6, 95.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(10, 5))
plt.hist(df_studentGrades['mathGrade'], bins=10, alpha=0.7, label='Math Grades', color='red')
plt.xlabel("Scores")
plt.ylabel("Students")
plt.title("Distribution of Math Grades")
plt.legend(loc='upper right')
plt.grid(True)
plt.savefig('math_grades_chart.png')
plt.show()

# %%
# Let's also use matplotlib to display a scatter plot of English vs. Math grades
# Scatter plots are useful for seeing the relationship between two variables
plt.figure(figsize=(10, 6))

# Step 1: Use .scatter(x_data, y_data) to create a scatter plot using the English grades on the x-axis, and Math grades on the y-axis
# (2 mark)
#

# Step 1: Properly label the x and y axes as well as the title of your plot.
# (3 marks)
#
plt.grid(True)

# Step 2: Output an image file for the scatter plot with a descriptive file name
# (1 mark)
#

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_studentGrades['englishGrade'], df_studentGrades['mathGrade'])
plt.ylabel("Math Grades")
plt.xlabel("English Grades")
plt.title("English vs. Math Scores")
plt.grid(True)
plt.savefig('math_vs_english_grades_scores.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))

for i in range(len(df_studentGrades)):
  if i % 2 == 0:
    plt.scatter(df_studentGrades['englishGrade'].iloc[i], df_studentGrades['mathGrade'].iloc[i], marker='o', color='blue')
  else:
    plt.scatter(df_studentGrades['englishGrade'].iloc[i], df_studentGrades['mathGrade'].iloc[i], marker='s', color='red')

plt.scatter([], [], marker='o', color='blue', label='English')
plt.scatter([], [], marker='s', color='red', label='Math')
plt.ylabel("Math Grades")
plt.xlabel("English Grades")
plt.title("English vs. Math Scores")
plt.grid(True)
plt.legend()
plt.savefig('math_vs_english_grades_scores.png')
plt.show()

# %%
# From the scatter plot, is there a relationship between the Math and English grades?
# (1 mark)
#

# %%
correlation = df_studentGrades['englishGrade'].corr(df_studentGrades['mathGrade'])
print(f"Correlation between English and Math grades: {correlation}")
print("There is a weak negative correlation between English and Math grades")
# Out:
# Correlation between English and Math grades: -0.2737227327533567
# There is a weak negative correlation between English and Math grades
